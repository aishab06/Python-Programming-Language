# %% [markdown]
# Question 1: Write a function that takes a dictionary and a key as input and returns the corresponding value.
# - Sample Input: my_dict = {'a': 1, 'b': 2, 'c': 3}, key = 'b'
# - Sample Output: 2

# %%
my_dict = {'a': 1, 'b': 2, 'c': 3}
key = 'b'
for i in my_dict:
  if i == key:
    print (my_dict[i])
# Out:
# 2

# %% [markdown]
# Question 2 : Write a function that updates a dictionary with a new key-value pair.
# - Sample Input: my_dict = {'a': 1, 'b': 2}, key = 'c', value = 3
# - Sample Output:{'a': 1, 'b': 2, 'c': 3}

# %%
my_dict = {'a': 1, 'b': 2}
key = 'c'
value = 3
my_dict[key] = value
print (my_dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# Question 3 : Write a function that checks if a key exists in a dictionary.
# - Sample Input: my_dict = {'a': 1, 'b': 2, 'c': 3}, key = 'd'
# - Sample Output: False

# %%
my_dict = {'a': 1, 'b': 2, 'c': 3}
key = 'd'
count = 0
for item in my_dict:
  if item == key:
    count = count + 1
if count > 0:
  print ('True')
else:
  print ('False')
# Out:
# False

# %% [markdown]
# Question 4 : Write a function that calculates the sum of all values in a dictionary.
# - Sample Input: my_dict = {'a': 1, 'b': 2, 'c': 3}
# - Sample Output: 6

# %%
my_dict = {'a': 1, 'b': 2, 'c': 3}
total = 0
for item in my_dict:
  total = my_dict[item] + total
print (total)
# Out:
# 6

# %% [markdown]
# Question 5 : Write a function that returns a list of all keys in a dictionary.
# - Sample Input: my_dict = {'a': 1, 'b': 2, 'c': 3}
# - Sample Output: ['a', 'b', 'c']

# %%
my_dict = {'a': 1, 'b': 2, 'c': 3}
value_lst = []
for item in my_dict:
  value_lst.append(item)
print (value_lst)
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# Question 6 : Write a function that returns a list of all values in a dictionary.
# - Sample Input: my_dict = {'a': 1, 'b': 2, 'c': 3}
# - Sample Output: [1, 2, 3]

# %%
my_dict = {'a': 1, 'b': 2, 'c': 3}
value_lst = []
for item in my_dict:
  value_lst.append(my_dict[item])
print (value_lst)
# Out:
# [1, 2, 3]

# %% [markdown]
# Question 7 : Write a function that returns the number of key-value pairs in a dictionary.
# - Sample Input: my_dict = {'a': 1, 'b': 2, 'c': 3}
# - Sample Output: 3

# %%
my_dict = {'a': 1, 'b': 2, 'c': 3}
print (len(my_dict))
cont = 0
for item in my_dict:
  cont = cont + 1
print (cont)
# Out:
# 3
# 3

# %% [markdown]
# Question 8 : Write a function that merges two dictionaries into one.
# - Sample Input: dict1 = {'a': 1, 'b': 2}, dict2 = {'c': 3, 'd': 4}
# - Sample Output: {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
dict1 = {'a': 1, 'b': 2}
dict2 = {'c': 3, 'd': 4}
for item in dict2:
  dict1[item]= dict2[item]
print (dict1)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %% [markdown]
# Question 9 : Write a function that sorts a dictionary by its values in ascending order.
# - Sample Input: my_dict = {'a': 5, 'b': 2, 'c': 7}
# - Sample Output: {'b': 2, 'a': 5, 'c': 7}

# %%
my_dict = {'a': 5, 'b': 2, 'c': 7}
sort_dict = []
for item in my_dict:
  sort_dict.append((item, my_dict[item]))
sort_dict = sorted(sort_dict, key=lambda x:x[1])
print (dict(sort_dict))
# Out:
# {'b': 2, 'a': 5, 'c': 7}

# %% [markdown]
# Question 10 : Write a function that returns the key in a dictionary with the maximum value.
# - Sample Input: my_dict = {'a': 5, 'b': 2, 'c': 7}
# - Sample Output: 'c'

# %%
my_dict = {'a': 5, 'b': 2, 'c': 7}
max_value = []
for item in my_dict:
  max_value.append(my_dict[item])
maxValue = max(max_value)
print (maxValue)
maxKey = ''
for k in my_dict:
  if my_dict[k] == maxValue:
    maxKey = k
print (maxKey)



max_key = max(my_dict, key=my_dict.get)
print(max_key)
# Out:
# 7
# c
# c
